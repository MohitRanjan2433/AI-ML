# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y, 'rD')

# %%
plt.plot(x,y, color='red',marker='D',linestyle='dotted')

# %%
plt.plot(x,y, color='red',marker='D',linestyle='dotted',markersize=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.legend(loc='lower left', shadow='True', fontsize='large')

# %%
days=[1,2,3,4,5,6,7]
max_t=[32,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

plt.legend(loc='best', shadow='True', fontsize='large')
plt.grid()

# %% [markdown]
# # BARCHART !!!

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(ypos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bin)")
plt.title("US Tech Stock")
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.legend()

# %% [markdown]
# # Horizontal bar chart using barh function

# %%
plt.barh(xpos,revenue,label="Revenue")
plt.yticks(xpos,company)
plt.ylabel("Revenue(bin)")
plt.title("US Tech Stocks")
plt.legend()

# %% [markdown]
# # Histogram !!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, bins = [80,100,125,150], rwidth=0.95, color='r')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.xlabel('sugar range')
plt.ylabel('Total No of Patient')
plt.title('Blood Sugar Analysis')
plt.hist([blood_sugar_men, blood_sugar_women] ,bins = [80,100,125,150], rwidth=0.95, color=['green', 'orange'], 
         label=['Men', 'Women'])
plt.legend()

# %% [markdown]
# # Pie Chart !

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,radius=1.0,autopct='%0.2f%%',explode=[0,0.2,0,0,0,], startangle=180)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Make a pie chart from importing pandas file....

df = pd.read_csv('stock_market.csv')
df
# Out:
#      Bill_name  Amount
# 0    House Tax   25000
# 1  School Fees   15000
# 2      Medical    4500
# 3     Vechicle    3200

# %%
bill_names=df['Bill_name']
amounts=df['Amount']
plt.pie(amounts, labels=bill_names,explode=[0,0.1,0,0],autopct='%.2f%%')

plt.show()

# %% [markdown]
# # IMPORTANT GRAPHS PLOTTING !!

# %%
# # Data
# year = [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
# percapinc = [3399.299037, 3768.297935, 4251.175484, 4804.463248, 5576.514583, 5998.144346, 7062.131392, 7100.12617, 7247.967035, 7602.912681, 8355.96812, 9434.390652, 9619.438377, 10416.53659, 10790.32872, 11018.95585, 11482.89153, 12974.80662, 15080.28345, 16426.72548, 16838.6732, 17266.09769, 16412.08309, 15875.58673, 15755.82027, 16369.31725, 16699.82668, 17310.75775, 16622.67187, 17581.02414, 18987.38241, 18601.39724, 19232.17556, 22739.42628, 25719.14715, 29198.05569, 32738.2629, 36144.48122, 37446.48609, 32755.17682, 38420.52289, 42334.71121, 42665.25597, 42676.46837, 41039.8936, 35175.18898, 34229.19363]

# # Create the plot
# plt.plot(year, percapinc)
# plt.xlabel('Year')
# plt.ylabel('Per Capita Income (US$)')
# plt.title('Per Capita Income over Time')

# # Display the plot
# plt.show()


# Read data from CSV file
data = pd.read_csv('canada_per_capita_income.csv')

# Extract year and percapinc columns
year = data['year']
per_capita_income = data['per_cap_inc']

# Create the plot
plt.plot(year, percapinc)
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.title('Per Capita Income over Time')

# Display the plot
plt.show()
